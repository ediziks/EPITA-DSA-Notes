# %%
"""
Gradient project
Instructions
The point of this project is to code a application in Python that takes the coordinates of a point in R 
(given by the user) and calculates the gradient of the function f(x,y) = x²y - xy² at this point.


It is required from you to write a Python code that:

- asks the user to enter the coordinates x and y of a point in R²
- calculates the gradient of the function f(x,y) = x²y - xy² at this point
- handles the case where the user writes non numerical values

The due date is the 23th of February (included). Please create a file with a link to a Github repository
with your code in it.

Feel free to share information that you think is relevant in the read.me and/or in the comments of your code.

You can use any type of file as long as it's written in Python and I can launch it (for example a .py file is 
ok as well as .ipynb file but please don't share a snapshot of your IDE: I've already seen this...).
"""
# Out:
# "\nGradient project\nInstructions\nThe point of this project is to code a application in Python that takes the coordinates of a point in R \n(given by the user) and calculates the gradient of the function f(x,y) = x²y - xy² at this point.\n\n\nIt is required from you to write a Python code that:\n\n- asks the user to enter the coordinates x and y of a point in R²\n- calculates the gradient of the function f(x,y) = x²y - xy² at this point\n- handles the case where the user writes non numerical values\n\nThe due date is the 23th of February (included). Please create a file with a link to a Github repository\nwith your code in it.\n\nFeel free to share information that you think is relevant in the read.me and/or in the comments of your code.\n\nYou can use any type of file as long as it's written in Python and I can launch it (for example a .py file is \nok as well as .ipynb file but please don't share a snapshot of your IDE: I've already seen this...).\n"

# %%
def gradient_function(x,y):
    """
    Calculates the gradient by partial derivatives of the function f(x,y) = x²y - xy² at this point
    """
    # Since ∇𝑓(𝑥, 𝑦) = 〈𝑓𝑥(𝑥, 𝑦), 𝑓𝑦(𝑥, 𝑦)〉 -> we will have ∇𝑓(𝑥, 𝑦) = 〈2𝑥𝑦 - 𝑦², 𝑥² - 2𝑥𝑦〉
    fx, fy = 2*x*y - y**2, x**2 - 2*x*y

    return fx, fy

# %%
def main():
    """
    Main function that asks user inputs and gives the gradient of the function f(x,y) = x²y - xy²
    """
    try:
        x = float(input("Enter the value of x: "))
        y = float(input("Enter the value of y: "))
        print("The gradient of the function f(x,y) = x²y - xy² at this point is: ", gradient_function(x, y))
    except ValueError:
        print("You have entered a non numerical value.")

main()
# Out:
# The gradient of the function f(x,y) = x²y - xy² at this point is:  (0.0, -3.0)

# %%
"""
Gradient vector field graph with the help of numpy and matplotlib
"""
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

xline, yline = np.meshgrid(np.linspace(-10, 10, 15), np.linspace(-10, 10, 15))

fx = 2*xline*yline - yline**2
fy = xline**2 - 2*xline*yline

plt.quiver(xline, yline, fx, fy)
plt.show()
