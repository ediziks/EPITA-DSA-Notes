# %%
from lxml import etree
import requests
from bs4 import BeautifulSoup as bs

# %%
def getContent(link: str) -> str:
    webPage = requests.get(link)
    return str(bs(webPage.content, "html.parser"))

# %%
content: str = getContent("https://en.wikipedia.org/wiki/List_of_international_airports_by_country")
html: etree.ElementBase = etree.HTML(content)

# %%
RELATIVE_ROOT = '//*[@id="mw-content-text"]/div[1]'
# allNodes: list[etree.ElementBase] = html.xpath(RELATIVE_ROOT+"/*")
allNodes = html.xpath(RELATIVE_ROOT+"/*")
length: int = len(allNodes)

# %%
rows = []
for i in range(0, length):
    currentRow = []
    node: etree.ElementBase = allNodes[i]
    if node.tag == 'table' and 'wikitable' in node.get('class'):
        for j in range(1, len(node.xpath("./tbody/tr"))):
            currentRegion = node.xpath("./preceding-sibling::h2[1]/span[@class='mw-headline']")[0].text
            # if/else for sub regions having their name within <a> tag and None for no sub regions in Oceania
            currentSubRegion = None if currentRegion == 'Oceania' \
                else (node.xpath("./preceding-sibling::h3[1]/span[@class='mw-headline']")[0].text \
                if node.xpath("./preceding-sibling::h3[1]/span[@class='mw-headline']")[0].text is not None \
                else node.xpath("./preceding-sibling::h3[1]/span[@class='mw-headline']/a")[0].text)
            # if/else for Oceania countries' having their name within <h3>
            currentCountry = node.xpath("./preceding-sibling::h3[1]/span[@class='mw-headline']")[0].text if currentRegion == 'Oceania' \
                else node.xpath("./preceding-sibling::h4[1]/span[@class='mw-headline']")[0].text
            # try/except for the cities having multiple airports
            try:
                currentCity = node.xpath(f"./tbody/tr[{j+1}]/td/a")[0].text
                currentAirport = node.xpath(f"./tbody/tr[{j+1}]/td[2]/a")[0].text
                currentIATA = node.xpath(f"./tbody/tr[{j+1}]/td[3]")[0].text.strip('\n')
            except IndexError:
                currentCity = node.xpath(f"./tbody/tr[{j+1}]//preceding::*[@rowspan][1]/a")[0].text
                currentAirport = node.xpath(f"./tbody/tr[{j+1}]/td[1]/a")[0].text
                currentIATA = node.xpath(f"./tbody/tr[{j+1}]/td[2]")[0].text.strip('\n')
            currentRow = [currentRegion, currentSubRegion, currentCountry, currentCity, currentAirport, currentIATA]
            rows.append(currentRow)

# %%
for i in rows[:]:
    print(i)
# Out:
# ['Africa', 'Northern Africa', 'Algeria', 'Adrar', 'Touat-Cheikh Sidi Mohamed Belkebir Airport', 'AZR']
# ['Africa', 'Northern Africa', 'Algeria', 'Algiers', 'Houari Boumediene Airport', 'ALG']
# ['Africa', 'Northern Africa', 'Algeria', 'Annaba', 'Rabah Bitat Airport', 'AAE']
# ['Africa', 'Northern Africa', 'Algeria', 'Batna', 'Batna Airport', 'BLJ']
# ['Africa', 'Northern Africa', 'Algeria', 'Béjaïa', 'Soummam Airport', 'BJA']
# ['Africa', 'Northern Africa', 'Algeria', 'Oumache', 'Biskra Airport', 'BSK']
# ['Africa', 'Northern Africa', 'Algeria', 'Chlef', 'Chlef International Airport', 'CFK']
# ['Africa', 'Northern Africa', 'Algeria', 'Constantine', 'Mohamed Boudiaf International Airport', 'CZL']
# ['Africa', 'Northern Africa', 'Algeria', 'Hassi Messaoud', 'Oued Irara Airport', 'HME']
# ['Africa', 'Northern Africa', 'Algeria', 'Jijel', 'Jijel Ferhat Abbas Airport', 'GJL']
# ['Africa', 'Northern Africa', 'Algeria', 'Oran', 'Oran Es Senia Airport', 'ORN']
# ['Africa', 'Northern Africa', 'Algeria', 'Sétif', 'Ain Arnat Airport', 'QSF']
# ['Africa', 'Northern Africa', 'Algeria', 'Tamanrasset', 'Tamanrasset Airport', 'TMR']
# ['Africa', 'Northern Africa', 'Algeria', 'Tlemcen', 'Zenata – Messali El Hadj Airport', 'TLM']
# ['Africa', 'Northern Africa', 'Egypt', 'Alexandria', 'Borg El Arab Airport', 'HBE']
# ['Africa', 'Northern Africa', 'Egypt', 'Alexandria', 'El Nouzha Airport', 'ALY']
# ['Africa', 'Northern Africa', 'Egypt', 'Asyut', 'Assiut Airport', 'ATZ']
# ['Africa', 'Northern Africa', 'Egypt', 'Aswan', 'Aswan International Airport', 'ASW']
# ['Africa', 'Northern Africa', 'Egypt', 'Cairo', 'Cairo International Airport', 'CAI']
# ['Africa', 'Northern Africa', 'Egypt', 'El Arish', 'El Arish International Airport', 'AAC']
# ['Africa', 'Northern Africa', 'Egypt', 'El Dabaa', 'El Alamein International Airport', 'DBB']
# ['Africa', 'Northern Africa', 'Egypt', 'Hurghada', 'Hurghada International Airport', 'HRG']
# ['Africa', 'Northern Africa', 'Egypt', 'Luxor', 'Luxor International Airport', 'LXR']
# ['Africa', 'Northern Africa', 'Egypt', 'Marsa Alam', 'Marsa Alam International Airport', 'RMF']
# ['Africa', 'Northern Africa', 'Egypt', 'Mersa Matruh', 'Mersa Matruh International Airport', 'MUH']
# ['Africa', 'Northern Africa', 'Egypt', 'Saint Catherine', 'St. Catherine International Airport', 'SKV']
# ['Africa', 'Northern Africa', 'Egypt', 'Sharm El Sheikh', 'Sharm El Sheikh International Airport', 'SSH']
# ['Africa', 'Northern Africa', 'Egypt', 'Sohag', 'Sohag International Airport', 'HMB']
# ['Africa', 'Northern Africa', 'Egypt', 'Taba', 'Taba International Airport', 'TCP']
# ['Africa', 'Northern Africa', 'Libya', 'Benghazi', 'Benina International Airport', 'BEN']
# ['Africa', 'Northern Africa', 'Libya', 'Sabha', 'Sabha Airport', 'SEB']
# ['Africa', 'Northern Africa', 'Libya', 'Tripoli', 'Tripoli International Airport', 'TIP']
# ['Africa', 'Northern Africa', 'Libya', 'Tajoura', 'Mitiga International Airport', 'MJI']
# ['Africa', 'Northern Africa', 'Morocco', 'Agadir', 'Agadir–Al Massira Airport', 'AGA']
# ['Africa', 'Northern Africa', 'Morocco', 'Casablanca', 'Mohammed V International Airport', 'CMN']
# ['Africa', 'Northern Africa', 'Morocco', 'Fes', 'Fès–Saïs Airport', 'FEZ']
# ['Africa', 'Northern Africa', 'Morocco', 'Marrakech', 'Marrakesh Menara Airport', 'RAK']
# ['Africa', 'Northern Africa', 'Morocco', 'Nador', 'Nador International Airport', 'NDR']
# ['Africa', 'Northern Africa', 'Morocco', 'Oujda', 'Angads Airport', 'OUD']
# ['Africa', 'Northern Africa', 'Morocco', 'Rabat', 'Rabat–Salé Airport', 'RBA']
# ['Africa', 'Northern Africa', 'Morocco', 'Tangier', 'Tangier Ibn Battouta Airport', 'TNG']
# ['Africa', 'Northern Africa', 'Morocco', 'Tetouan', 'Sania Ramel Airport', 'TTU']
# ['Africa', 'Northern Africa', 'Morocco', 'Dakhla', 'Dakhla Airport', 'VIL']
# ['Africa', 'Northern Africa', 'Morocco', 'Laayoune', 'Hassan I Airport', 'EUN']
# ['Africa', 'Northern Africa', 'Sudan', 'Khartoum', 'Khartoum International Airport', 'KRT']
# ['Africa', 'Northern Africa', 'Sudan', 'Port Sudan', 'Port Sudan New International Airport', 'PZU']
# ['Africa', 'Northern Africa', 'Tunisia', 'Djerba', 'Djerba–Zarzis International Airport', 'DJE']
# ['Africa', 'Northern Africa', 'Tunisia', 'Enfidha', 'Enfidha–Hammamet International Airport', 'NBE']
# ['Africa', 'Northern Africa', 'Tunisia', 'Monastir', 'Monastir Habib Bourguiba International Airport', 'MIR']
# ['Africa', 'Northern Africa', 'Tunisia', 'Sfax', 'Sfax–Thyna International Airport', 'SFA']
# ['Africa', 'Northern Africa', 'Tunisia', 'Tabarka', 'Tabarka–Aïn Draham International Airport', 'TBJ']
# ['Africa', 'Northern Africa', 'Tunisia', 'Tozeur', 'Tozeur–Nefta International Airport', 'TOE']
# ['Africa', 'Northern Africa', 'Tunisia', 'Tunis', 'Tunis–Carthage International Airport', 'TUN']
# ['Africa', 'Eastern Africa', 'Burundi', 'Bujumbura', 'Bujumbura International Airport', 'BJM']
# ['Africa', 'Eastern Africa', 'Comoros', 'Moroni', 'Prince Said Ibrahim International Airport', 'HAH']
# ['Africa', 'Eastern Africa', 'Djibouti', 'Djibouti City', 'Djibouti–Ambouli International Airport', 'JIB']
# ['Africa', 'Eastern Africa', 'Eritrea', 'Asmara', 'Asmara International Airport', 'ASM']
# ['Africa', 'Eastern Africa', 'Ethiopia', 'Addis Ababa', 'Addis Ababa Bole International Airport', 'ADD']
# ['Africa', 'Eastern Africa', 'Ethiopia', 'Dire Dawa', 'Dire Dawa Airport', 'DIR']
# ['Africa', 'Eastern Africa', 'Kenya', 'Eldoret', 'Eldoret International Airport', 'EDL']
# ['Africa', 'Eastern Africa', 'Kenya', 'Mombasa', 'Moi International Airport', 'MBA']
# ['Africa', 'Eastern Africa', 'Kenya', 'Kisumu', 'Kisumu International Airport', 'KIS']
# ['Africa', 'Eastern Africa', 'Kenya', 'Nairobi', 'Jomo Kenyatta International Airport', 'NBO']
# ['Africa', 'Eastern Africa', 'Madagascar', 'Antananarivo', 'Ivato International Airport', 'TNR']
# ['Africa', 'Eastern Africa', 'Madagascar', 'Antsiranana', 'Arrachart Airport', 'DIE']
# ['Africa', 'Eastern Africa', 'Madagascar', 'Mahajanga', 'Amborovy Airport', 'MJN']
# ['Africa', 'Eastern Africa', 'Madagascar', 'Nosy Be', 'Fascene Airport', 'NOS']
# ['Africa', 'Eastern Africa', 'Madagascar', 'Toamasina', 'Toamasina Airport', 'TMM']
# ['Africa', 'Eastern Africa', 'Madagascar', 'Tôlanaro', 'Tôlanaro Airport', 'FTU']
# ['Africa', 'Eastern Africa', 'Madagascar', 'Toliara', 'Toliara Airport', 'TLE']
# ['Africa', 'Eastern Africa', 'Malawi', 'Blantyre', 'Chileka International Airport', 'BLZ']
# ['Africa', 'Eastern Africa', 'Malawi', 'Lilongwe', 'Lilongwe International Airport', 'LLW']
# ['Africa', 'Eastern Africa', 'Mauritius', 'Plaine Magnien', 'Sir Seewoosagur Ramgoolam International Airport', 'MRU']
# ['Africa', 'Eastern Africa', 'Mayotte', 'Dzaoudzi', 'Dzaoudzi–Pamandzi International Airport', 'DZA']
# ['Africa', 'Eastern Africa', 'Mozambique', 'Maputo', 'Maputo International Airport', 'MPM']
# ['Africa', 'Eastern Africa', 'Mozambique', 'Beira', 'Beira Airport', 'BEW']
# ['Africa', 'Eastern Africa', 'Mozambique', 'Inhambane', 'Inhambane Airport', 'INH']
# ['Africa', 'Eastern Africa', 'Mozambique', 'Nampula', 'Nampula Airport', 'APL']
# ['Africa', 'Eastern Africa', 'Mozambique', 'Pemba', 'Pemba Airport', 'POL']
# ['Africa', 'Eastern Africa', 'Mozambique', 'Tete', 'Chingozi Airport', 'TET']
# ['Africa', 'Eastern Africa', 'Mozambique', 'Vilankulo', 'Vilankulo Airport', 'VNX']
# ['Africa', 'Eastern Africa', 'Réunion', 'Saint-Denis', 'Roland Garros Airport', 'RUN']
# ['Africa', 'Eastern Africa', 'Rwanda', 'Kigali', 'Kigali International Airport', 'KGL']
# ['Africa', 'Eastern Africa', 'Seychelles', 'Victoria', 'Seychelles International Airport', 'SEZ']
# ['Africa', 'Eastern Africa', 'Somalia', 'Bosaso', 'Bosaso Airport', 'BSA']
# ['Africa', 'Eastern Africa', 'Somalia', 'Galkayo', 'Abdullahi Yusuf Airport', 'GBY']
# ['Africa', 'Eastern Africa', 'Somalia', 'Garoowe', 'Garowe Airport', 'GGR']
# ['Africa', 'Eastern Africa', 'Somalia', 'Hargeisa', 'Hargeisa Airport', 'HGA']
# ['Africa', 'Eastern Africa', 'Somalia', 'Kismayo', 'Kismayo Airport', 'KMU']
# ['Africa', 'Eastern Africa', 'Somalia', 'Mogadishu', 'Aden Adde International Airport', 'MGQ']
# ['Africa', 'Eastern Africa', 'South Sudan', 'Juba', 'Juba International Airport', 'JUB']
# ['Africa', 'Eastern Africa', 'Tanzania', 'Arusha', 'Arusha Airport', 'ARK']
# ['Africa', 'Eastern Africa', 'Tanzania', 'Dar es Salaam', 'Julius Nyerere International Airport', 'DAR']
# ['Africa', 'Eastern Africa', 'Tanzania', 'Hai District', 'Kilimanjaro International Airport', 'JRO']
# ['Africa', 'Eastern Africa', 'Tanzania', 'Mwanza', 'Mwanza Airport', 'MWZ']
# ['Africa', 'Eastern Africa', 'Tanzania', 'Unguja', 'Abeid Amani Karume International Airport', 'ZNZ']
# ['Africa', 'Eastern Africa', 'Uganda', 'Arua', 'Arua Airport', 'RUA']
# ['Africa', 'Eastern Africa', 'Uganda', 'Entebbe', 'Entebbe International Airport', 'EBB']
# ['Africa', 'Eastern Africa', 'Uganda', 'Gulu', 'Gulu Airport', 'ULU']
# ['Africa', 'Eastern Africa', 'Zambia', 'Livingstone', 'Harry Mwanga Nkumbula International Airport', 'LVI']
# ['Africa', 'Eastern Africa', 'Zambia', 'Lusaka', 'Kenneth Kaunda International Airport', 'LUN']
# ['Africa', 'Eastern Africa', 'Zambia', 'Ndola', 'Simon Mwansa Kapwepwe International Airport', 'NLA']
# ['Africa', 'Eastern Africa', 'Zimbabwe', 'Harare', 'Robert Gabriel Mugabe International Airport', 'HRE']
# ['Africa', 'Eastern Africa', 'Zimbabwe', 'Victoria Falls', 'Victoria Falls Airport', 'VFA']
# ['Africa', 'Eastern Africa', 'Zimbabwe', 'Bulawayo', 'Joshua Mqabuko Nkomo International Airport', 'BUQ']
# ['Africa', 'Central Africa', 'Angola', 'Luanda', 'Quatro de Fevereiro Airport', 'LAD']
# ['Africa', 'Central Africa', 'Angola', 'Lubango', 'Lubango Airport', 'SDD']
# ['Africa', 'Central Africa', 'Cameroon', 'Douala', 'Douala International Airport', 'DLA']
# ['Africa', 'Central Africa', 'Cameroon', 'Yaoundé', 'Yaoundé Nsimalen International Airport', 'NSI']
# ['Africa', 'Central Africa', 'Central African Republic', 'Bangui', "Bangui M'Poko International Airport", 'BGF']
# ['Africa', 'Central Africa', 'Chad', "N'Djamena", "N'Djamena International Airport", 'NDJ']
# ['Africa', 'Central Africa', 'Democratic Republic of the Congo', 'Goma', 'Goma International Airport', 'GOM']
# ['Africa', 'Central Africa', 'Democratic Republic of the Congo', 'Kinshasa', "N'djili Airport", 'FIH']
# ['Africa', 'Central Africa', 'Democratic Republic of the Congo', 'Kisangani', 'Kisangani Bangoka International Airport', 'FKI']
# ['Africa', 'Central Africa', 'Democratic Republic of the Congo', 'Lubumbashi', 'Lubumbashi International Airport', 'FBM']
# ['Africa', 'Central Africa', 'Republic of the Congo', 'Brazzaville', 'Maya-Maya Airport', 'BZV']
# ['Africa', 'Central Africa', 'Republic of the Congo', 'Pointe-Noire', 'Agostinho-Neto International Airport', 'PNR']
# ['Africa', 'Central Africa', 'Equatorial Guinea', 'Malabo', 'Malabo International Airport', 'SSG']
# ['Africa', 'Central Africa', 'Gabon', 'Franceville', "M'Vengue El Hadj Omar Bongo Ondimba International Airport", 'MVB']
# ['Africa', 'Central Africa', 'Gabon', 'Libreville', 'Léon-Mba International Airport', 'LBV']
# ['Africa', 'Central Africa', 'Gabon', 'Port-Gentil', 'Port-Gentil International Airport', 'POG']
# ['Africa', 'Central Africa', 'São Tomé and Príncipe', 'São Tomé', 'São Tomé International Airport', 'TMS']
# ['Africa', 'Southern Africa', 'Benin', 'Cotonou', 'Cadjehoun Airport', 'COO']
# ['Africa', 'Southern Africa', 'Eswatini', 'Manzini', 'King Mswati III International Airport', 'SHO']
# ['Africa', 'Southern Africa', 'Lesotho', 'Maseru', 'Moshoeshoe I International Airport', 'MSU']
# ['Africa', 'Southern Africa', 'Namibia', 'Windhoek', 'Hosea Kutako International Airport', 'WDH']
# ['Africa', 'Southern Africa', 'Namibia', 'Walvis Bay', 'Walvis Bay Airport', 'WVB']
# ['Africa', 'Southern Africa', 'South Africa', 'Cape Town', 'Cape Town International Airport', 'CPT']
# ['Africa', 'Southern Africa', 'South Africa', 'Durban', 'King Shaka International Airport', 'DUR']
# ['Africa', 'Southern Africa', 'South Africa', 'Johannesburg', 'O. R. Tambo International Airport', 'JNB']
# ['Africa', 'Southern Africa', 'South Africa', 'Johannesburg', 'Lanseria International Airport', 'HLA']
# ['Africa', 'Southern Africa', 'South Africa', 'Nelspruit', 'Kruger Mpumalanga International Airport', 'MQP']
# ['Africa', 'Southern Africa', 'South Africa', 'Bloemfontein', 'Bram Fischer International Airport', 'BFN']
# ['Africa', 'Southern Africa', 'South Africa', 'East London', 'East London Airport', 'ELS']
# ['Africa', 'Western Africa', 'Botswana', 'Gaborone', 'Sir Seretse Khama International Airport', 'GBE']
# ['Africa', 'Western Africa', 'Botswana', 'Maun', 'Maun Airport', 'MUB']
# ['Africa', 'Western Africa', 'Botswana', 'Francistown', 'Francistown International Airport', 'FRW']
# ['Africa', 'Western Africa', 'Botswana', 'Kasane', 'Kasane Airport', 'BBK']
# ['Africa', 'Western Africa', 'Burkina Faso', 'Bobo-Dioulasso', 'Bobo Dioulasso Airport', 'BOY']
# ['Africa', 'Western Africa', 'Burkina Faso', 'Ouagadougou', 'Thomas Sankara International Airport Ouagadougou', 'OUA']
# ['Africa', 'Western Africa', 'Cape Verde', 'Boa Vista', 'Aristides Pereira International Airport', 'BVC']
# ['Africa', 'Western Africa', 'Cape Verde', 'Sal Island', 'Amílcar Cabral International Airport', 'SID']
# ['Africa', 'Western Africa', 'Cape Verde', 'Praia', 'Nelson Mandela International Airport', 'RAI']
# ['Africa', 'Western Africa', 'Cape Verde', 'São Vicente', 'Cesária Évora Airport', 'VXE']
# ['Africa', 'Western Africa', "Côte d'Ivoire", 'Abidjan', 'Félix-Houphouët-Boigny International Airport', 'ABJ']
# ['Africa', 'Western Africa', 'The Gambia', 'Banjul', 'Banjul International Airport', 'BJL']
# ['Africa', 'Western Africa', 'Ghana', 'Accra', 'Kotoka International Airport', 'ACC']
# ['Africa', 'Western Africa', 'Ghana', 'Kumasi', 'Kumasi International Airport', 'KMS']
# ['Africa', 'Western Africa', 'Ghana', 'Takoradi', 'Takoradi Airport', 'TKD']
# ['Africa', 'Western Africa', 'Ghana', 'Sunyani', 'Sunyani Airport', 'NYI']
# ['Africa', 'Western Africa', 'Ghana', 'Ho', 'Ho Airport', 'HZO']
# ['Africa', 'Western Africa', 'Ghana', 'Wa', 'Wa Airport', 'WZA']
# ['Africa', 'Western Africa', 'Ghana', 'Tamale', 'Tamale Airport', 'TML']
# ['Africa', 'Western Africa', 'Guinea', 'Conakry', 'Conakry International Airport', 'CKY']
# ['Africa', 'Western Africa', 'Guinea-Bissau', 'Bissau', 'Osvaldo Vieira International Airport', 'OXB']
# ['Africa', 'Western Africa', 'Guinea-Bissau', 'Bubaque', 'Bubaque Airport', 'BQE']
# ['Africa', 'Western Africa', 'Liberia', 'Monrovia', 'Roberts International Airport', 'ROB']
# ['Africa', 'Western Africa', 'Mali', 'Bamako', 'Modibo Keita International Airport', 'BKO']
# ['Africa', 'Western Africa', 'Mauritania', 'Nouakchott', 'Nouakchott–Oumtounsy International Airport', 'NKC']
# ['Africa', 'Western Africa', 'Mauritania', 'Nouadhibou', 'Nouadhibou International Airport', 'NDB']
# ['Africa', 'Western Africa', 'Niger', 'Niamey', 'Diori Hamani International Airport', 'NIM']
# ['Africa', 'Western Africa', 'Nigeria', 'Abuja', 'Nnamdi Azikiwe International Airport', 'ABV']
# ['Africa', 'Western Africa', 'Nigeria', 'Calabar', 'Margaret Ekpo International Airport', 'CBQ']
# ['Africa', 'Western Africa', 'Nigeria', 'Asaba, Delta', 'Asaba International Airport', 'ABB']
# ['Africa', 'Western Africa', 'Nigeria', 'Kano', 'Mallam Aminu Kano International Airport', 'KAN']
# ['Africa', 'Western Africa', 'Nigeria', 'Lagos', 'Murtala Muhammed International Airport', 'LOS']
# ['Africa', 'Western Africa', 'Nigeria', 'Port Harcourt', 'Port Harcourt International Airport', 'PHC']
# ['Africa', 'Western Africa', 'Nigeria', 'Enugu', 'Akanu Ibiam International Airport', 'ENU']
# ['Africa', 'Western Africa', 'Nigeria', 'Sokoto', 'Sadiq Abubakar III International Airport', 'SKO']
# ['Africa', 'Western Africa', 'Saint Helena, Ascension and Tristan da Cunha', 'Saint Helena', 'Saint Helena Airport', 'HLE']
# ['Africa', 'Western Africa', 'Senegal', 'Dakar', 'Blaise Diagne International Airport', 'DSS']
# ['Africa', 'Western Africa', 'Sierra Leone', 'Freetown', 'Lungi International Airport', 'FNA']
# ['Africa', 'Western Africa', 'Togo', 'Lomé', 'Lomé–Tokoin International Airport', 'LFW']
# ['Americas', 'Caribbean', 'Anguilla', 'The Valley', 'Clayton J. Lloyd International Airport', 'AXA']
# ['Americas', 'Caribbean', 'Antigua and Barbuda', 'Antigua', 'V. C. Bird International Airport', 'ANU']
# ['Americas', 'Caribbean', 'Aruba', 'Oranjestad', 'Queen Beatrix International Airport', 'AUA']
# ['Americas', 'Caribbean', 'Bahamas', 'Nassau', 'Lynden Pindling International Airport', 'NAS']
# ['Americas', 'Caribbean', 'Bahamas', 'Chub Cay', 'Chub Cay International Airport', 'CCZ']
# ['Americas', 'Caribbean', 'Bahamas', 'Exuma', 'Exuma International Airport', 'GGT']
# ['Americas', 'Caribbean', 'Bahamas', 'Freeport', 'Grand Bahama International Airport', 'FPO']
# ['Americas', 'Caribbean', 'Bahamas', 'South Eleuthera', 'Rock Sound International Airport', 'RSD']
# ['Americas', 'Caribbean', 'Bahamas', 'Marsh Harbour', 'Marsh Harbour International Airport', 'MHH']
# ['Americas', 'Caribbean', 'Barbados', 'Bridgetown', 'Grantley Adams International Airport', 'BGI']
# ['Americas', 'Caribbean', 'British Virgin Islands', 'Road Town', 'Terrance B. Lettsome International Airport', 'EIS']
# ['Americas', 'Caribbean', 'Caribbean Netherlands', 'Kralendijk', 'Flamingo International Airport', 'BON']
# ['Americas', 'Caribbean', 'Caribbean Netherlands', 'Oranjestad, Sint Eustatius', 'F. D. Roosevelt Airport', 'EUX']
# ['Americas', 'Caribbean', 'Caribbean Netherlands', 'Saba', 'Juancho E. Yrausquin Airport', 'SAB']
# ['Americas', 'Caribbean', 'Cayman Islands', 'Cayman Brac', 'Charles Kirkconnell International Airport', 'CYB']
# ['Americas', 'Caribbean', 'Cayman Islands', 'Georgetown', 'Owen Roberts International Airport', 'GCM']
# ['Americas', 'Caribbean', 'Cuba', 'Camagüey', 'Ignacio Agramonte International Airport', 'CMW']
# ['Americas', 'Caribbean', 'Cuba', 'Cayo Coco', 'Jardines del Rey Airport', 'CCC']
# ['Americas', 'Caribbean', 'Cuba', 'Cayo Largo del Sur', 'Vilo Acuña Airport', 'CYO']
# ['Americas', 'Caribbean', 'Cuba', 'Cienfuegos', 'Jaime González Airport', 'CFG']
# ['Americas', 'Caribbean', 'Cuba', 'Havana', 'José Martí International Airport', 'HAV']
# ['Americas', 'Caribbean', 'Cuba', 'Holguín', 'Frank País Airport', 'HOG']
# ['Americas', 'Caribbean', 'Cuba', 'Santa Clara', 'Abel Santamaría Airport', 'SNU']
# ['Americas', 'Caribbean', 'Cuba', 'Santiago de Cuba', 'Antonio Maceo Airport', 'SCU']
# ['Americas', 'Caribbean', 'Cuba', 'Varadero', 'Juan Gualberto Gómez Airport', 'VRA']
# ['Americas', 'Caribbean', 'Curaçao', 'Willemstad', 'Curaçao International Airport', 'CUR']
# ['Americas', 'Caribbean', 'Dominica', 'Roseau', 'Douglas–Charles Airport', 'DOM']
# ['Americas', 'Caribbean', 'Dominican Republic', 'Barahona', 'María Montez International Airport', 'BRX']
# ['Americas', 'Caribbean', 'Dominican Republic', 'La Romana', 'La Romana International Airport', 'LRM']
# ['Americas', 'Caribbean', 'Dominican Republic', 'Punta Cana', 'Punta Cana International Airport', 'PUJ']
# ['Americas', 'Caribbean', 'Dominican Republic', 'Samana', 'Samaná El Catey International Airport', 'AZS']
# ['Americas', 'Caribbean', 'Dominican Republic', 'San Felipe de Puerto Plata', 'Gregorio Luperón International Airport', 'POP']
# ['Americas', 'Caribbean', 'Dominican Republic', 'Santiago de los Caballeros', 'Cibao International Airport', 'STI']
# ['Americas', 'Caribbean', 'Dominican Republic', 'Santo Domingo', 'Las Américas International Airport', 'SDQ']
# ['Americas', 'Caribbean', 'Grenada', 'Grenada', 'Maurice Bishop International Airport', 'GND']
# ['Americas', 'Caribbean', 'Guadeloupe', 'Pointe-à-Pitre', 'Pointe-à-Pitre International Airport', 'PTP']
# ['Americas', 'Caribbean', 'Haiti', 'Cap-Haïtien', 'Cap-Haïtien International Airport', 'CAP']
# ['Americas', 'Caribbean', 'Haiti', 'Port-au-Prince', 'Toussaint Louverture International Airport', 'PAP']
# ['Americas', 'Caribbean', 'Jamaica', 'Kingston', 'Norman Manley International Airport', 'KIN']
# ['Americas', 'Caribbean', 'Jamaica', 'Montego Bay', 'Sangster International Airport', 'MBJ']
# ['Americas', 'Caribbean', 'Martinique', 'Fort-de-France', 'Martinique Aimé Césaire International Airport', 'FDF']
# ['Americas', 'Caribbean', 'Montserrat', 'Brades', 'John A. Osborne Airport', 'MNI']
# ['Americas', 'Caribbean', 'Puerto Rico', 'Aguadilla', 'Rafael Hernández Airport', 'BQN']
# ['Americas', 'Caribbean', 'Puerto Rico', 'San Juan', 'Luis Muñoz Marín International Airport', 'SJU']
# ['Americas', 'Caribbean', 'Saint Barthélemy', 'Saint Jean', 'Gustaf III Airport', 'SBH']
# ['Americas', 'Caribbean', 'Saint Kitts and Nevis', 'Saint Kitts', 'Robert L. Bradshaw International Airport', 'SKB']
# ['Americas', 'Caribbean', 'Saint Lucia', 'Vieux Fort Quarter', 'Hewanorra International Airport', 'UVF']
# ['Americas', 'Caribbean', 'Saint Vincent and the Grenadines', 'Kingstown', 'Argyle International Airport', 'SVD']
# ['Americas', 'Caribbean', 'Saint Vincent and the Grenadines', 'Canouan', 'Canouan Airport', 'CIW']
# ['Americas', 'Caribbean', 'Sint Maarten', 'Philipsburg', 'Princess Juliana International Airport', 'SXM']
# ['Americas', 'Caribbean', 'Trinidad and Tobago', 'Port of Spain', 'Piarco International Airport', 'POS']
# ['Americas', 'Caribbean', 'Trinidad and Tobago', 'Tobago', 'A.N.R. Robinson International Airport', 'TAB']
# ['Americas', 'Caribbean', 'Turks and Caicos Islands', 'Providenciales', 'Providenciales Airport', 'PLS']
# ['Americas', 'Caribbean', 'U.S. Virgin Islands', 'Saint Thomas', 'Cyril E. King Airport', 'STT']
# ['Americas', 'Caribbean', 'U.S. Virgin Islands', 'Saint Croix', 'Henry E. Rohlsen Airport', 'STX']
# ['Americas', 'Central America', 'Belize', 'Belize City', 'Philip S. W. Goldson International Airport', 'BZE']
# ['Americas', 'Central America', 'Costa Rica', 'Liberia', 'Daniel Oduber Quirós International Airport', 'LIR']
# ['Americas', 'Central America', 'Costa Rica', 'San José', 'Juan Santamaría International Airport', 'SJO']
# ['Americas', 'Central America', 'El Salvador', 'San Salvador', 'El Salvador International Airport', 'SAL']
# ['Americas', 'Central America', 'Guatemala', 'Flores', 'Mundo Maya International Airport', 'FRS']
# ['Americas', 'Central America', 'Guatemala', 'Guatemala City', 'La Aurora International Airport', 'GUA']
# ['Americas', 'Central America', 'Honduras', 'La Ceiba', 'Golosón International Airport', 'LCE']
# ['Americas', 'Central America', 'Honduras', 'Roatán', 'Juan Manuel Gálvez International Airport', 'RTB']
# ['Americas', 'Central America', 'Honduras', 'San Pedro Sula', 'Ramón Villeda Morales International Airport', 'SAP']
# ['Americas', 'Central America', 'Honduras', 'Tegucigalpa', 'Toncontín International Airport', 'TGU']
# ['Americas', 'Central America', 'Nicaragua', 'Managua', 'Augusto C. Sandino International Airport', 'MGA']
# ['Americas', 'Central America', 'Nicaragua', 'Bluefields', 'Bluefields Airport', 'BEF']
# ['Americas', 'Central America', 'Nicaragua', 'Corn Island', 'Corn Island Airport', 'RNI']
# ['Americas', 'Central America', 'Panama', 'Bocas del Toro', 'Bocas del Toro "Isla Colón" International Airport', 'BOC']
# ['Americas', 'Central America', 'Panama', 'David, Chiriquí', 'Enrique Malek International Airport', 'DAV']
# ['Americas', 'Central America', 'Panama', 'Panama City', 'Albrook "Marcos A. Gelabert" International Airport', 'PAC']
# ['Americas', 'Central America', 'Panama', 'Panama City', 'Panama Pacifico International Airport', 'BLB']
# ['Americas', 'Central America', 'Panama', 'Panama City', 'Tocumen International Airport', 'PTY']
# ['Americas', 'Central America', 'Panama', 'Rio Hato', 'Scarlett Martínez International Airport', 'RIH']
# ['Americas', 'North America', 'Bermuda', "St. George's", 'L.F. Wade International Airport', 'BDA']
# ['Americas', 'North America', 'Canada', 'Abbotsford', 'Abbotsford International Airport', 'YXX']
# ['Americas', 'North America', 'Canada', 'Calgary', 'Calgary International Airport', 'YYC']
# ['Americas', 'North America', 'Canada', 'Edmonton', 'Edmonton International Airport', 'YEG']
# ['Americas', 'North America', 'Canada', 'Fredericton', 'Fredericton International Airport', 'YFC']
# ['Americas', 'North America', 'Canada', 'Gander', 'Gander International Airport', 'YQX']
# ['Americas', 'North America', 'Canada', 'Halifax', 'Halifax Stanfield International Airport', 'YHZ']
# ['Americas', 'North America', 'Canada', 'Hamilton', 'John C. Munro Hamilton International Airport', 'YHM']
# ['Americas', 'North America', 'Canada', 'Kelowna', 'Kelowna International Airport', 'YLW']
# ['Americas', 'North America', 'Canada', 'London', 'London International Airport', 'YXU']
# ['Americas', 'North America', 'Canada', 'Moncton', 'Greater Moncton Roméo LeBlanc International Airport', 'YQM']
# ['Americas', 'North America', 'Canada', 'Montreal', 'Montréal–Trudeau International Airport', 'YUL']
# ['Americas', 'North America', 'Canada', 'Ottawa', 'Ottawa Macdonald–Cartier International Airport', 'YOW']
# ['Americas', 'North America', 'Canada', 'Quebec City', 'Québec City Jean Lesage International Airport', 'YQB']
# ['Americas', 'North America', 'Canada', 'Regina', 'Regina International Airport', 'YQR']
# ['Americas', 'North America', 'Canada', 'Saskatoon', 'Saskatoon John G. Diefenbaker International Airport', 'YXE']
# ['Americas', 'North America', 'Canada', "St. John's", "St. John's International Airport", 'YYT']
# ['Americas', 'North America', 'Canada', 'Thunder Bay', 'Thunder Bay International Airport', 'YQT']
# ['Americas', 'North America', 'Canada', 'Toronto', 'Toronto Pearson International Airport', 'YYZ']
# ['Americas', 'North America', 'Canada', 'Vancouver', 'Vancouver International Airport', 'YVR']
# ['Americas', 'North America', 'Canada', 'Victoria', 'Victoria International Airport', 'YYJ']
# ['Americas', 'North America', 'Canada', 'Whitehorse', 'Erik Nielsen Whitehorse International Airport', 'YXY']
# ['Americas', 'North America', 'Canada', 'Windsor', 'Windsor International Airport', 'YQC']
# ['Americas', 'North America', 'Canada', 'Winnipeg', 'Winnipeg James Armstrong Richardson International Airport', 'YWG']
# ['Americas', 'North America', 'Greenland', 'Kangerlussuaq', 'Kangerlussuaq Airport', 'SFJ']
# ['Americas', 'North America', 'Greenland', 'Nuuk', 'Nuuk Airport', 'GOH']
# ['Americas', 'North America', 'Greenland', 'Ilulissat', 'Ilulissat Airport', 'JAV']
# ['Americas', 'North America', 'Greenland', 'Narsarsuaq', 'Narsarsuaq Airport', 'UAK']
# ['Americas', 'North America', 'Mexico', 'Acapulco', 'Acapulco International Airport', 'ACA']
# ['Americas', 'North America', 'Mexico', 'Aguascalientes', 'Aguascalientes International Airport', 'AGU']
# ['Americas', 'North America', 'Mexico', 'Cancún', 'Cancún International Airport', 'CUN']
# ['Americas', 'North America', 'Mexico', 'Chihuahua City', 'Chihuahua International Airport', 'CUU']
# ['Americas', 'North America', 'Mexico', 'Ciudad del Carmen', 'Ciudad del Carmen International Airport', 'CME']
# ['Americas', 'North America', 'Mexico', 'Cozumel', 'Cozumel International Airport', 'CZM']
# ['Americas', 'North America', 'Mexico', 'Culiacán', 'Culiacán International Airport', 'CUL']
# ['Americas', 'North America', 'Mexico', 'Durango', 'Durango International Airport', 'DGO']
# ['Americas', 'North America', 'Mexico', 'Guadalajara', 'Miguel Hidalgo y Costilla Guadalajara International Airport', 'GDL']
# ['Americas', 'North America', 'Mexico', 'Hermosillo', 'Hermosillo International Airport', 'HMO']
# ['Americas', 'North America', 'Mexico', 'Huatulco', 'Bahías de Huatulco International Airport', 'HUX']
# ['Americas', 'North America', 'Mexico', 'Ixtapa', 'Ixtapa-Zihuatanejo International Airport', 'ZIH']
# ['Americas', 'North America', 'Mexico', 'León', 'Bajío International Airport', 'BJX']
# ['Americas', 'North America', 'Mexico', 'Loreto', 'Loreto International Airport', 'LTO']
# ['Americas', 'North America', 'Mexico', 'Los Cabos', 'Los Cabos International Airport', 'SJD']
# ['Americas', 'North America', 'Mexico', 'Manzanillo', 'Playa de Oro International Airport', 'ZLO']
# ['Americas', 'North America', 'Mexico', 'Mazatlán', 'Mazatlán International Airport', 'MZT']
# ['Americas', 'North America', 'Mexico', 'Mérida', 'Mérida International Airport', 'MID']
# ['Americas', 'North America', 'Mexico', 'Mexico City', 'Mexico City International Airport', 'MEX']
# ['Americas', 'North America', 'Mexico', 'Monterrey', 'Monterrey International Airport', 'MTY']
# ['Americas', 'North America', 'Mexico', 'Morelia', 'General Francisco Mujica International Airport', 'MLM']
# ['Americas', 'North America', 'Mexico', 'Oaxaca City', 'Oaxaca International Airport', 'OAX']
# ['Americas', 'North America', 'Mexico', 'Puebla', 'Puebla International Airport', 'PBC']
# ['Americas', 'North America', 'Mexico', 'Puerto Vallarta', 'Licenciado Gustavo Díaz Ordaz International Airport', 'PVR']
# ['Americas', 'North America', 'Mexico', 'Querétaro City', 'Querétaro Intercontinental Airport', 'QRO']
# ['Americas', 'North America', 'Mexico', 'Reynosa', 'General Lucio Blanco International Airport', 'REX']
# ['Americas', 'North America', 'Mexico', 'Saltillo', 'Saltillo Airport', 'SLW']
# ['Americas', 'North America', 'Mexico', 'San Luis Potosí City', 'San Luis Potosí International Airport', 'SLP']
# ['Americas', 'North America', 'Mexico', 'Tampico', 'Tampico International Airport', 'TAM']
# ['Americas', 'North America', 'Mexico', 'Tijuana', 'Tijuana International Airport', 'TIJ']
# ['Americas', 'North America', 'Mexico', 'Toluca', 'Toluca International Airport', 'TLC']
# ['Americas', 'North America', 'Mexico', 'Torreón', 'Torreón International Airport', 'TRC']
# ['Americas', 'North America', 'Mexico', 'Tuxtla Gutiérrez', 'Tuxtla Gutiérrez International Airport', 'TGZ']
# ['Americas', 'North America', 'Mexico', 'Uruapan', 'Uruapan International Airport', 'UPN']
# ['Americas', 'North America', 'Mexico', 'Veracruz', 'Veracruz International Airport', 'VER']
# ['Americas', 'North America', 'Mexico', 'Villahermosa', 'Villahermosa International Airport', 'VSA']
# ['Americas', 'North America', 'Mexico', 'Zacatecas City', 'Zacatecas International Airport', 'ZCL']
# ['Americas', 'North America', 'Saint Pierre and Miquelon', 'Saint-Pierre', 'Saint-Pierre Airport', 'FSP']
# ['Americas', 'North America', 'United States', 'Akron', 'Akron Executive Airport', 'AKC']
# ['Americas', 'North America', 'United States', 'Albany', 'Albany International Airport', 'ALB']
# ['Americas', 'North America', 'United States', 'Albuquerque', 'Albuquerque International Sunport', 'ABQ']
# ['Americas', 'North America', 'United States', 'Anchorage', 'Ted Stevens Anchorage International Airport', 'ANC']
# ['Americas', 'North America', 'United States', 'Appleton', 'Appleton International Airport', 'ATW']
# ['Americas', 'North America', 'United States', 'Atlanta', 'Hartsfield–Jackson Atlanta International Airport', 'ATL']
# ['Americas', 'North America', 'United States', 'Atlantic City', 'Atlantic City International Airport', 'ACY']
# ['Americas', 'North America', 'United States', 'Austin (TX)', 'Austin–Bergstrom International Airport', 'AUS']
# ['Americas', 'North America', 'United States', 'Baltimore', 'Baltimore/Washington International Airport', 'BWI']
# ['Americas', 'North America', 'United States', 'Bangor', 'Bangor International Airport', 'BGR']
# ['Americas', 'North America', 'United States', 'Bellingham', 'Bellingham International Airport', 'BLI']
# ['Americas', 'North America', 'United States', 'Birmingham', 'Birmingham–Shuttlesworth International Airport', 'BHM']
# ['Americas', 'North America', 'United States', 'Boise', 'Boise Airport', 'BOI']
# ['Americas', 'North America', 'United States', 'Boston', 'Logan International Airport', 'BOS']
# ['Americas', 'North America', 'United States', 'Buffalo', 'Buffalo Niagara International Airport', 'BUF']
# ['Americas', 'North America', 'United States', 'Charlotte', 'Charlotte Douglas International Airport', 'CLT']
# ['Americas', 'North America', 'United States', 'Charleston (SC)', 'Charleston International Airport', 'CHS']
# ['Americas', 'North America', 'United States', 'Chicago', 'Midway International Airport', 'MDW']
# ['Americas', 'North America', 'United States', 'Chicago', "O'Hare International Airport", 'ORD']
# ['Americas', 'North America', 'United States', 'Cincinnati', 'Cincinnati/Northern Kentucky International Airport', 'CVG']
# ['Americas', 'North America', 'United States', 'Cleveland', 'Cleveland Hopkins International Airport', 'CLE']
# ['Americas', 'North America', 'United States', 'Columbus (OH)', 'John Glenn Columbus International Airport', 'CMH']
# ['Americas', 'North America', 'United States', 'Columbus (OH)', 'Rickenbacker International Airport', 'LCK']
# ['Americas', 'North America', 'United States', 'Dallas', 'Dallas/Fort Worth International Airport', 'DFW']
# ['Americas', 'North America', 'United States', 'Dayton (OH)', 'Dayton International Airport', 'DAY']
# ['Americas', 'North America', 'United States', 'Denver', 'Denver International Airport', 'DEN']
# ['Americas', 'North America', 'United States', 'Des Moines (IA)', 'Des Moines International Airport', 'DSM']
# ['Americas', 'North America', 'United States', 'Detroit', 'Detroit Metropolitan Airport', 'DTW']
# ['Americas', 'North America', 'United States', 'El Paso', 'El Paso International Airport', 'ELP']
# ['Americas', 'North America', 'United States', 'Fairbanks', 'Fairbanks International Airport', 'FAI']
# ['Americas', 'North America', 'United States', 'Fort Lauderdale', 'Fort Lauderdale–Hollywood International Airport', 'FLL']
# ['Americas', 'North America', 'United States', 'Fort Myers', 'Southwest Florida International Airport', 'RSW']
# ['Americas', 'North America', 'United States', 'Fresno', 'Fresno Yosemite International Airport', 'FAT']
# ['Americas', 'North America', 'United States', 'Grand Rapids', 'Gerald R. Ford International Airport', 'GRR']
# ['Americas', 'North America', 'United States', 'Green Bay', 'Green Bay–Austin Straubel International Airport', 'GRB']
# ['Americas', 'North America', 'United States', 'Greensboro', 'Piedmont Triad International Airport', 'GSO']
# ['Americas', 'North America', 'United States', 'Harrisburg', 'Harrisburg International Airport', 'MDT']
# ['Americas', 'North America', 'United States', 'Hartford (CT)', 'Bradley International Airport', 'BDL']
# ['Americas', 'North America', 'United States', 'Hilo', 'Hilo International Airport', 'ITO']
# ['Americas', 'North America', 'United States', 'Honolulu', 'Daniel K. Inouye International Airport', 'HNL']
# ['Americas', 'North America', 'United States', 'Houston', 'George Bush Intercontinental Airport', 'IAH']
# ['Americas', 'North America', 'United States', 'Houston', 'William P. Hobby Airport', 'HOU']
# ['Americas', 'North America', 'United States', 'Huntsville (AL)', 'Huntsville International Airport', 'HSV']
# ['Americas', 'North America', 'United States', 'Indianapolis', 'Indianapolis International Airport', 'IND']
# ['Americas', 'North America', 'United States', 'Jackson (MS)', 'Jackson–Medgar Wiley Evers International Airport', 'JAN']
# ['Americas', 'North America', 'United States', 'Jacksonville', 'Jacksonville International Airport', 'JAX']
# ['Americas', 'North America', 'United States', 'Juneau', 'Juneau International Airport', 'JNU']
# ['Americas', 'North America', 'United States', 'Kansas City (MO)', 'Kansas City International Airport', 'MCI']
# ['Americas', 'North America', 'United States', 'Ketchikan', 'Ketchikan International Airport', 'KTN']
# ['Americas', 'North America', 'United States', 'Key West', 'Key West International Airport', 'EYW']
# ['Americas', 'North America', 'United States', 'Kailua-Kona', 'Kona International Airport', 'KOA']
# ['Americas', 'North America', 'United States', 'Knoxville', 'McGhee Tyson Airport', 'TYS']
# ['Americas', 'North America', 'United States', 'Lakeland', 'Lakeland Linder International Airport', 'LAL']
# ['Americas', 'North America', 'United States', 'Lansing', 'Capital Region International Airport', 'LAN']
# ['Americas', 'North America', 'United States', 'Las Vegas', 'McCarran International Airport', 'LAS']
# ['Americas', 'North America', 'United States', 'Little Rock', 'Clinton National Airport', 'LIT']
# ['Americas', 'North America', 'United States', 'Los Angeles', 'Los Angeles International Airport', 'LAX']
# ['Americas', 'North America', 'United States', 'Louisville', 'Louisville International Airport', 'SDF']
# ['Americas', 'North America', 'United States', 'Melbourne (FL)', 'Melbourne Orlando International Airport', 'MLB']
# ['Americas', 'North America', 'United States', 'Memphis', 'Memphis International Airport', 'MEM']
# ['Americas', 'North America', 'United States', 'Miami', 'Miami International Airport', 'MIA']
# ['Americas', 'North America', 'United States', 'Midland', 'Midland International Air and Space Port', 'MAF']
# ['Americas', 'North America', 'United States', 'Milwaukee', 'General Mitchell International Airport', 'MKE']
# ['Americas', 'North America', 'United States', 'Minneapolis', 'Minneapolis–Saint Paul International Airport', 'MSP']
# ['Americas', 'North America', 'United States', 'Myrtle Beach', 'Myrtle Beach International Airport', 'MYR']
# ['Americas', 'North America', 'United States', 'Nashville', 'Nashville International Airport', 'BNA']
# ['Americas', 'North America', 'United States', 'New Orleans', 'Louis Armstrong New Orleans International Airport', 'MSY']
# ['Americas', 'North America', 'United States', 'New York City', 'John F. Kennedy International Airport', 'JFK']
# ['Americas', 'North America', 'United States', 'New York City', 'LaGuardia Airport', 'LGA']
# ['Americas', 'North America', 'United States', 'Newark', 'Newark Liberty International Airport', 'EWR']
# ['Americas', 'North America', 'United States', 'Newburgh', 'Stewart International Airport', 'SWF']
# ['Americas', 'North America', 'United States', 'Norfolk (VA)', 'Norfolk International Airport', 'ORF']
# ['Americas', 'North America', 'United States', 'Oakland', 'Oakland International Airport', 'OAK']
# ['Americas', 'North America', 'United States', 'Oklahoma City', 'Will Rogers World Airport', 'OKC']
# ['Americas', 'North America', 'United States', 'Omaha', 'Eppley Airfield', 'OMA']
# ['Americas', 'North America', 'United States', 'Ontario', 'Ontario International Airport', 'ONT']
# ['Americas', 'North America', 'United States', 'Orange County', 'John Wayne Airport', 'SNA']
# ['Americas', 'North America', 'United States', 'Orlando', 'Orlando International Airport', 'MCO']
# ['Americas', 'North America', 'United States', 'Orlando', 'Orlando Sanford International Airport', 'SFB']
# ['Americas', 'North America', 'United States', 'Palm Springs', 'Palm Springs International Airport', 'PSP']
# ['Americas', 'North America', 'United States', 'Panama City (FL)', 'Northwest Florida Beaches International Airport', 'ECP']
# ['Americas', 'North America', 'United States', 'Pensacola', 'Pensacola International Airport', 'PNS']
# ['Americas', 'North America', 'United States', 'Philadelphia', 'Philadelphia International Airport', 'PHL']
# ['Americas', 'North America', 'United States', 'Phoenix', 'Phoenix Sky Harbor International Airport', 'PHX']
# ['Americas', 'North America', 'United States', 'Phoenix', 'Phoenix–Mesa Gateway Airport', 'AZA']
# ['Americas', 'North America', 'United States', 'Pittsburgh', 'Pittsburgh International Airport', 'PIT']
# ['Americas', 'North America', 'United States', 'Portland (ME)', 'Portland International Jetport', 'PWM']
# ['Americas', 'North America', 'United States', 'Portland (OR)', 'Portland International Airport', 'PDX']
# ['Americas', 'North America', 'United States', 'Providence', 'Rhode Island T. F. Green International Airport', 'PVD']
# ['Americas', 'North America', 'United States', 'Racine', 'Batten International Airport', 'RAC']
# ['Americas', 'North America', 'United States', 'Raleigh', 'Raleigh–Durham International Airport', 'RDU']
# ['Americas', 'North America', 'United States', 'Reno', 'Reno–Tahoe International Airport', 'RNO']
# ['Americas', 'North America', 'United States', 'Richmond (VA)', 'Richmond International Airport', 'RIC']
# ['Americas', 'North America', 'United States', 'Rochester (MN)', 'Rochester International Airport', 'RST']
# ['Americas', 'North America', 'United States', 'Rochester (NY)', 'Greater Rochester International Airport', 'ROC']
# ['Americas', 'North America', 'United States', 'Rockford (IL)', 'Chicago Rockford International Airport', 'RFD']
# ['Americas', 'North America', 'United States', 'Sacramento', 'Sacramento International Airport', 'SMF']
# ['Americas', 'North America', 'United States', 'Salt Lake City', 'Salt Lake City International Airport', 'SLC']
# ['Americas', 'North America', 'United States', 'San Antonio', 'San Antonio International Airport', 'SAT']
# ['Americas', 'North America', 'United States', 'San Bernardino', 'San Bernardino International Airport', 'SBD']
# ['Americas', 'North America', 'United States', 'San Diego', 'San Diego International Airport', 'SAN']
# ['Americas', 'North America', 'United States', 'San Francisco', 'San Francisco International Airport', 'SFO']
# ['Americas', 'North America', 'United States', 'San Jose (CA)', 'San Jose International Airport', 'SJC']
# ['Americas', 'North America', 'United States', 'Sarasota', 'Sarasota–Bradenton International Airport', 'SRQ']
# ['Americas', 'North America', 'United States', 'Savannah (GA)', 'Savannah/Hilton Head International Airport', 'SAV']
# ['Americas', 'North America', 'United States', 'Seattle', 'Kenmore Air Harbor Seaplane Base', 'LKE']
# ['Americas', 'North America', 'United States', 'Seattle', 'King County International Airport', 'BFI']
# ['Americas', 'North America', 'United States', 'Seattle', 'Seattle–Tacoma International Airport', 'SEA']
# ['Americas', 'North America', 'United States', 'Sheboygan', 'Sheboygan County Memorial Airport', 'SBM']
# ['Americas', 'North America', 'United States', 'Snohomish County (WA)', 'Paine Field', 'PAE']
# ['Americas', 'North America', 'United States', 'Spokane', 'Spokane International Airport', 'GEG']
# ['Americas', 'North America', 'United States', 'St. Louis', 'St. Louis Lambert International Airport', 'STL']
# ['Americas', 'North America', 'United States', 'St. Petersburg (FL)', 'St. Pete–Clearwater International Airport', 'PIE']
# ['Americas', 'North America', 'United States', 'Syracuse', 'Syracuse Hancock International Airport', 'SYR']
# ['Americas', 'North America', 'United States', 'Tallahassee', 'Tallahassee International Airport', 'TLH']
# ['Americas', 'North America', 'United States', 'Tampa', 'Tampa International Airport', 'TPA']
# ['Americas', 'North America', 'United States', 'Tucson', 'Tucson International Airport', 'TUS']
# ['Americas', 'North America', 'United States', 'Tulsa', 'Tulsa International Airport', 'TUL']
# ['Americas', 'North America', 'United States', 'Washington, D.C.', 'Ronald Reagan Washington National Airport', 'DCA']
# ['Americas', 'North America', 'United States', 'Washington, D.C.', 'Dulles International Airport', 'IAD']
# ['Americas', 'North America', 'United States', 'West Palm Beach', 'Palm Beach International Airport', 'PBI']
# ['Americas', 'North America', 'United States', 'Wilkes-Barre', 'Wilkes-Barre/Scranton International Airport', 'AVP']
# ['Americas', 'North America', 'United States', 'Wilmington (NC)', 'Wilmington International Airport', 'ILM']
# ['Americas', 'South America', 'Argentina', 'Buenos Aires', 'Ministro Pistarini International Airport', 'EZE']
# ['Americas', 'South America', 'Argentina', 'Buenos Aires', 'Aeroparque Jorge Newbery', 'AEP']
# ['Americas', 'South America', 'Argentina', 'Bariloche', 'San Carlos de Bariloche Airport', 'BRC']
# ['Americas', 'South America', 'Argentina', 'Córdoba', 'Ingeniero Aeronáutico Ambrosio L.V. Taravella International Airport', 'COR']
# ['Americas', 'South America', 'Argentina', 'Mendoza', 'Governor Francisco Gabrielli International Airport', 'MDZ']
# ['Americas', 'South America', 'Argentina', 'Puerto Iguazú', 'Cataratas del Iguazú International Airport', 'IGR']
# ['Americas', 'South America', 'Argentina', 'Resistencia', 'Resistencia International Airport', 'RES']
# ['Americas', 'South America', 'Argentina', 'Río Gallegos', 'Piloto Civil Norberto Fernández International Airport', 'RGL']
# ['Americas', 'South America', 'Argentina', 'Ushuaia', 'Ushuaia – Malvinas Argentinas International Airport', 'USH']
# ['Americas', 'South America', 'Bolivia', 'La Paz', 'El Alto International Airport', 'LPB']
# ['Americas', 'South America', 'Bolivia', 'Santa Cruz de la Sierra', 'Viru Viru International Airport', 'VVI']
# ['Americas', 'South America', 'Bolivia', 'Cochabamba', 'Jorge Wilstermann International Airport', 'CBB']
# ['Americas', 'South America', 'Brazil', 'Aracaju', 'Santa Maria Airport', 'AJU']
# ['Americas', 'South America', 'Brazil', 'Belém', 'Val de Cães International Airport', 'BEL']
# ['Americas', 'South America', 'Brazil', 'Belo Horizonte', 'Tancredo Neves International Airport', 'CNF']
# ['Americas', 'South America', 'Brazil', 'Boa Vista', 'Boa Vista International Airport', 'BVB']
# ['Americas', 'South America', 'Brazil', 'Brasília', 'Brasília International Airport', 'BSB']
# ['Americas', 'South America', 'Brazil', 'Campinas', 'Viracopos International Airport', 'VCP']
# ['Americas', 'South America', 'Brazil', 'Campo Grande', 'Campo Grande International Airport', 'CGR']
# ['Americas', 'South America', 'Brazil', 'Cuiabá', 'Marechal Rondon International Airport', 'CGB']
# ['Americas', 'South America', 'Brazil', 'Curitiba', 'Afonso Pena International Airport', 'CWB']
# ['Americas', 'South America', 'Brazil', 'Florianópolis', 'Hercílio Luz International Airport', 'FLN']
# ['Americas', 'South America', 'Brazil', 'Fortaleza', 'Pinto Martins International Airport', 'FOR']
# ['Americas', 'South America', 'Brazil', 'Foz do Iguaçu', 'Foz do Iguaçu International Airport', 'IGU']
# ['Americas', 'South America', 'Brazil', 'Goiânia', 'Santa Genoveva Airport', 'GYN']
# ['Americas', 'South America', 'Brazil', 'João Pessoa', 'Presidente Castro Pinto International Airport', 'JPA']
# ['Americas', 'South America', 'Brazil', 'Maceió', 'Zumbi dos Palmares International Airport', 'MCZ']
# ['Americas', 'South America', 'Brazil', 'Manaus', 'Eduardo Gomes International Airport', 'MAO']
# ['Americas', 'South America', 'Brazil', 'Natal', 'Greater Natal International Airport', 'NAT']
# ['Americas', 'South America', 'Brazil', 'Petrolina', 'Petrolina Airport', 'PNZ']
# ['Americas', 'South America', 'Brazil', 'Porto Alegre', 'Salgado Filho Porto Alegre International Airport', 'POA']
# ['Americas', 'South America', 'Brazil', 'Porto Velho', 'Governador Jorge Teixeira de Oliveira International Airport', 'PVH']
# ['Americas', 'South America', 'Brazil', 'Recife', 'Guararapes International Airport', 'REC']
# ['Americas', 'South America', 'Brazil', 'Rio Branco', 'Rio Branco International Airport', 'RBR']
# ['Americas', 'South America', 'Brazil', 'Rio de Janeiro', 'Rio de Janeiro/Galeão International Airport', 'GIG']
# ['Americas', 'South America', 'Brazil', 'Rio de Janeiro', 'Santos Dumont Airport', 'SDU']
# ['Americas', 'South America', 'Brazil', 'Salvador', 'Deputado Luís Eduardo Magalhães International Airport', 'SSA']
# ['Americas', 'South America', 'Brazil', 'São Luís', 'Marechal Cunha Machado International Airport', 'SLZ']
# ['Americas', 'South America', 'Brazil', 'São Paulo', 'São Paulo–Congonhas Airport', 'CGH']
# ['Americas', 'South America', 'Brazil', 'São Paulo', 'São Paulo/Guarulhos International Airport', 'GRU']
# ['Americas', 'South America', 'Brazil', 'Teresina', 'Teresina Airport', 'THE']
# ['Americas', 'South America', 'Brazil', 'Uberlândia', 'Uberlândia Airport', 'UDI']
# ['Americas', 'South America', 'Brazil', 'Vitória', 'Eurico de Aguiar Salles Airport', 'VIX']
# ['Americas', 'South America', 'Chile', 'Antofagasta', 'Andrés Sabella Gálvez International Airport', 'ANF']
# ['Americas', 'South America', 'Chile', 'Concepción', 'Carriel Sur International Airport', 'CCP']
# ['Americas', 'South America', 'Chile', 'Puerto Montt', 'El Tepual International Airport', 'PMC']
# ['Americas', 'South America', 'Chile', 'Punta Arenas', 'Presidente Carlos Ibáñez del Campo International Airport', 'PUQ']
# ['Americas', 'South America', 'Chile', 'Santiago', 'Arturo Merino Benítez International Airport', 'SCL']
# ['Americas', 'South America', 'Colombia', 'Armenia', 'El Edén International Airport', 'AXM']
# ['Americas', 'South America', 'Colombia', 'Barranquilla', 'Ernesto Cortissoz International Airport', 'BAQ']
# ['Americas', 'South America', 'Colombia', 'Bogotá', 'El Dorado International Airport', 'BOG']
# ['Americas', 'South America', 'Colombia', 'Bucaramanga', 'Palonegro International Airport', 'BGA']
# ...
# ['Europe', 'Eastern Europe', 'Russia', 'Pskov', 'Pskov Airport', 'PKV']
# ['Europe', 'Eastern Europe', 'Russia', 'Rostov-on-Don', 'Platov International Airport', 'ROV']
# ['Europe', 'Eastern Europe', 'Russia', 'Saint Petersburg', 'Pulkovo Airport', 'LED']
# ['Europe', 'Eastern Europe', 'Russia', 'Samara', 'Samara Kurumoch Airport', 'KUF']
# ['Europe', 'Eastern Europe', 'Russia', 'Saratov', 'Saratov Gagarin Airport', 'GSV']
# ['Europe', 'Eastern Europe', 'Russia', 'Sochi', 'Sochi International Airport', 'AER']
# ['Europe', 'Eastern Europe', 'Russia', 'Stavropol', 'Stavropol Shpakovskoye Airport', 'STW']
# ['Europe', 'Eastern Europe', 'Russia', 'Surgut', 'Surgut International Airport', 'SGC']
# ['Europe', 'Eastern Europe', 'Russia', 'Syktyvkar', 'Syktyvkar Airport', 'SCW']
# ['Europe', 'Eastern Europe', 'Russia', 'Tomsk', 'Bogashevo Airport', 'TOF']
# ['Europe', 'Eastern Europe', 'Russia', 'Tyumen', 'Roshchino International Airport', 'TJM']
# ['Europe', 'Eastern Europe', 'Russia', 'Ulan-Ude', 'Baikal International Airport', 'UUD']
# ['Europe', 'Eastern Europe', 'Russia', 'Ulyanovsk', 'Ulyanovsk Baratayevka Airport', 'ULV']
# ['Europe', 'Eastern Europe', 'Russia', 'Ufa', 'Ufa International Airport', 'UFA']
# ['Europe', 'Eastern Europe', 'Russia', 'Vladivostok', 'Vladivostok International Airport', 'VVO']
# ['Europe', 'Eastern Europe', 'Russia', 'Vladikavkaz', 'Beslan Airport', 'OGZ']
# ['Europe', 'Eastern Europe', 'Russia', 'Volgograd', 'Volgograd International Airport', 'VOG']
# ['Europe', 'Eastern Europe', 'Russia', 'Voronezh', 'Voronezh International Airport', 'VOZ']
# ['Europe', 'Eastern Europe', 'Russia', 'Yakutsk', 'Yakutsk Airport', 'YKS']
# ['Europe', 'Eastern Europe', 'Russia', 'Yaroslavl', 'Tunoshna Airport', 'IAR']
# ['Europe', 'Eastern Europe', 'Russia', 'Yekaterinburg', 'Koltsovo International Airport', 'SVX']
# ['Europe', 'Eastern Europe', 'Russia', 'Yuzhno-Sakhalinsk', 'Yuzhno-Sakhalinsk Airport', 'UUS']
# ['Europe', 'Eastern Europe', 'Serbia', 'Belgrade', 'Belgrade Nikola Tesla Airport', 'BEG']
# ['Europe', 'Eastern Europe', 'Serbia', 'Niš', 'Niš Constantine the Great Airport', 'INI']
# ['Europe', 'Eastern Europe', 'Serbia', 'Kraljevo', 'Morava Airport', 'KVO']
# ['Europe', 'Eastern Europe', 'Turkey', 'Adana', 'Şakirpaşa Airport', 'ADA']
# ['Europe', 'Eastern Europe', 'Turkey', 'Alanya', 'Gazipaşa Airport', 'GZP']
# ['Europe', 'Eastern Europe', 'Turkey', 'Ankara', 'Esenboğa International Airport', 'ESB']
# ['Europe', 'Eastern Europe', 'Turkey', 'Antalya', 'Antalya Airport', 'AYT']
# ['Europe', 'Eastern Europe', 'Turkey', 'Bodrum', 'Milas-Bodrum Airport', 'BJV']
# ['Europe', 'Eastern Europe', 'Turkey', 'Bursa', 'Yenişehir Airport', 'YEI']
# ['Europe', 'Eastern Europe', 'Turkey', 'Dalaman', 'Dalaman Airport', 'DLM']
# ['Europe', 'Eastern Europe', 'Turkey', 'Denizli', 'Denizli Çardak Airport', 'DNZ']
# ['Europe', 'Eastern Europe', 'Turkey', 'Diyarbakır', 'Diyarbakır Airport', 'DIY']
# ['Europe', 'Eastern Europe', 'Turkey', 'Elazığ', 'Elazığ Airport', 'EZS']
# ['Europe', 'Eastern Europe', 'Turkey', 'Gaziantep', 'Oğuzeli Airport', 'GZT']
# ['Europe', 'Eastern Europe', 'Turkey', 'Istanbul', 'Istanbul Airport', 'IST']
# ['Europe', 'Eastern Europe', 'Turkey', 'Istanbul', 'Sabiha Gökçen International Airport', 'SAW']
# ['Europe', 'Eastern Europe', 'Turkey', 'İzmir', 'Adnan Menderes Airport', 'ADB']
# ['Europe', 'Eastern Europe', 'Turkey', 'Kayseri', 'Erkilet Airport', 'ASR']
# ['Europe', 'Eastern Europe', 'Turkey', 'Konya', 'Konya Airport', 'KYA']
# ['Europe', 'Eastern Europe', 'Turkey', 'Kütahya', 'Zafer Airport', 'KZR']
# ['Europe', 'Eastern Europe', 'Turkey', 'Malatya', 'Erhaç Airport', 'MLX']
# ['Europe', 'Eastern Europe', 'Turkey', 'Nevşehir', 'Kapadokya Airport', 'NAV']
# ['Europe', 'Eastern Europe', 'Turkey', 'Samsun', 'Samsun-Çarşamba Airport', 'SZF']
# ['Europe', 'Eastern Europe', 'Turkey', 'Trabzon', 'Trabzon Airport', 'TZX']
# ['Europe', 'Eastern Europe', 'Turkey', 'Zonguldak', 'Zonguldak Airport', 'ONQ']
# ['Europe', 'Eastern Europe', 'Ukraine', 'Chernivtsi', 'Chernivtsi International Airport', 'CWC']
# ['Europe', 'Eastern Europe', 'Ukraine', 'Dnipro', 'Dnipro International Airport', 'DNK']
# ['Europe', 'Eastern Europe', 'Ukraine', 'Ivano-Frankivsk', 'Ivano-Frankivsk International Airport', 'IFO']
# ['Europe', 'Eastern Europe', 'Ukraine', 'Kharkiv', 'Kharkiv International Airport', 'HRK']
# ['Europe', 'Eastern Europe', 'Ukraine', 'Kryvyi Rih', 'Kryvyi Rih International Airport', 'KWG']
# ['Europe', 'Eastern Europe', 'Ukraine', 'Kyiv', 'Boryspil International Airport', 'KBP']
# ['Europe', 'Eastern Europe', 'Ukraine', 'Kyiv', 'Kyiv International Airport', 'IEV']
# ['Europe', 'Eastern Europe', 'Ukraine', 'Lviv', 'Lviv Danylo Halytskyi International Airport', 'LWO']
# ['Europe', 'Eastern Europe', 'Ukraine', 'Mykolaiv', 'Mykolaiv International Airport', 'NLV']
# ['Europe', 'Eastern Europe', 'Ukraine', 'Odessa', 'Odesa International Airport', 'ODS']
# ['Europe', 'Eastern Europe', 'Ukraine', 'Poltava', 'Poltava Airport', 'PLV']
# ['Europe', 'Eastern Europe', 'Ukraine', 'Simferopol', 'Simferopol International Airport', 'SIP']
# ['Europe', 'Eastern Europe', 'Ukraine', 'Uzhhorod', 'Uzhhorod International Airport', 'UDJ']
# ['Europe', 'Eastern Europe', 'Ukraine', 'Zaporizhzhia', 'Zaporizhzhia International Airport', 'OZH']
# ['Europe', 'Nordic region', 'Denmark', 'Aalborg', 'Aalborg Airport', 'AAL']
# ['Europe', 'Nordic region', 'Denmark', 'Aarhus', 'Aarhus Airport', 'AAR']
# ['Europe', 'Nordic region', 'Denmark', 'Billund', 'Billund Airport', 'BLL']
# ['Europe', 'Nordic region', 'Denmark', 'Copenhagen', 'Copenhagen Airport', 'CPH']
# ['Europe', 'Nordic region', 'Faroe Islands', 'Vágar', 'Vágar Airport', 'FAE']
# ['Europe', 'Nordic region', 'Finland', 'Åland', 'Mariehamn Airport', 'MHQ']
# ['Europe', 'Nordic region', 'Finland', 'Helsinki', 'Helsinki-Vantaa Airport', 'HEL']
# ['Europe', 'Nordic region', 'Finland', 'Kittilä', 'Kittilä Airport', 'KTT']
# ['Europe', 'Nordic region', 'Finland', 'Kuopio', 'Kuopio Airport', 'KUO']
# ['Europe', 'Nordic region', 'Finland', 'Kuusamo', 'Kuusamo Airport', 'KAO']
# ['Europe', 'Nordic region', 'Finland', 'Lappeenranta', 'Lappeenranta Airport', 'LPP']
# ['Europe', 'Nordic region', 'Finland', 'Oulu', 'Oulu Airport', 'OUL']
# ['Europe', 'Nordic region', 'Finland', 'Rovaniemi', 'Rovaniemi Airport', 'RVN']
# ['Europe', 'Nordic region', 'Finland', 'Tampere', 'Tampere–Pirkkala Airport', 'TMP']
# ['Europe', 'Nordic region', 'Finland', 'Turku', 'Turku Airport', 'TKU']
# ['Europe', 'Nordic region', 'Finland', 'Vaasa', 'Vaasa Airport', 'VAA']
# ['Europe', 'Nordic region', 'Iceland', 'Akureyri', 'Akureyri Airport', 'AEY']
# ['Europe', 'Nordic region', 'Iceland', 'Reykjavík', 'Keflavik International Airport', 'KEF']
# ['Europe', 'Nordic region', 'Iceland', 'Reykjavík', 'Reykjavík Airport', 'RKV']
# ['Europe', 'Nordic region', 'Norway', 'Ålesund', 'Ålesund Airport', 'AES']
# ['Europe', 'Nordic region', 'Norway', 'Bergen', 'Bergen Airport', 'BGO']
# ['Europe', 'Nordic region', 'Norway', 'Bodø', 'Bodø Airport', 'BOO']
# ['Europe', 'Nordic region', 'Norway', 'Haugesund', 'Haugesund Airport', 'HAU']
# ['Europe', 'Nordic region', 'Norway', 'Kristiansand', 'Kristiansand Airport, Kjevik', 'KRS']
# ['Europe', 'Nordic region', 'Norway', 'Kristiansand', 'Kristiansund Airport, Kvernberget', 'KSU']
# ['Europe', 'Nordic region', 'Norway', 'Oslo', 'Oslo Airport, Gardermoen', 'OSL']
# ['Europe', 'Nordic region', 'Norway', 'Oslo', 'Sandefjord Airport, Torp', 'TRF']
# ['Europe', 'Nordic region', 'Norway', 'Stavanger', 'Stavanger Airport', 'SVG']
# ['Europe', 'Nordic region', 'Norway', 'Tromsø', 'Tromsø Airport', 'TOS']
# ['Europe', 'Nordic region', 'Norway', 'Trondheim', 'Trondheim Airport', 'TRD']
# ['Europe', 'Nordic region', 'Sweden', 'Gothenburg', 'Göteborg Landvetter Airport', 'GOT']
# ['Europe', 'Nordic region', 'Sweden', 'Luleå', 'Luleå Airport', 'LLA']
# ['Europe', 'Nordic region', 'Sweden', 'Malmö', 'Malmö Airport', 'MMX']
# ['Europe', 'Nordic region', 'Sweden', 'Norrköping', 'Norrköping Airport', 'NRK']
# ['Europe', 'Nordic region', 'Sweden', 'Östersund', 'Åre Östersund Airport', 'OSD']
# ['Europe', 'Nordic region', 'Sweden', 'Stockholm', 'Stockholm Arlanda Airport', 'ARN']
# ['Europe', 'Nordic region', 'Sweden', 'Stockholm', 'Stockholm Bromma Airport', 'BMA']
# ['Europe', 'Nordic region', 'Sweden', 'Stockholm', 'Stockholm Skavsta Airport', 'NYO']
# ['Europe', 'Nordic region', 'Sweden', 'Stockholm', 'Stockholm Västerås Airport', 'VST']
# ['Europe', 'Nordic region', 'Sweden', 'Sundsvall', 'Sundsvall–Timrå Airport', 'SDL']
# ['Europe', 'Nordic region', 'Sweden', 'Umeå', 'Umeå Airport', 'UME']
# ['Europe', 'Nordic region', 'Sweden', 'Växjö', 'Växjö Airport', 'VXO']
# ['Europe', 'Nordic region', 'Sweden', 'Visby', 'Visby Airport', 'VBY']
# ['Europe', 'United Kingdom', 'England and Wales', 'Birmingham', 'Birmingham International Airport', 'BHX']
# ['Europe', 'United Kingdom', 'England and Wales', 'Bournemouth', 'Bournemouth Airport', 'BOH']
# ['Europe', 'United Kingdom', 'England and Wales', 'Bristol', 'Bristol Airport', 'BRS']
# ['Europe', 'United Kingdom', 'England and Wales', 'Cardiff', 'Cardiff Airport', 'CWL']
# ['Europe', 'United Kingdom', 'England and Wales', 'Doncaster', 'Robin Hood Airport Doncaster Sheffield', 'DSA']
# ['Europe', 'United Kingdom', 'England and Wales', 'Middlesbrough', 'Durham Tees Valley Airport', 'MME']
# ['Europe', 'United Kingdom', 'England and Wales', 'Nottingham', 'East Midlands Airport', 'EMA']
# ['Europe', 'United Kingdom', 'England and Wales', 'Exeter', 'Exeter International Airport', 'EXT']
# ['Europe', 'United Kingdom', 'England and Wales', 'Leeds', 'Leeds Bradford International Airport', 'LBA']
# ['Europe', 'United Kingdom', 'England and Wales', 'Liverpool', 'Liverpool John Lennon Airport', 'LPL']
# ['Europe', 'United Kingdom', 'England and Wales', 'London', 'London City Airport', 'LCY']
# ['Europe', 'United Kingdom', 'England and Wales', 'London', 'Gatwick Airport', 'LGW']
# ['Europe', 'United Kingdom', 'England and Wales', 'London', 'Heathrow Airport', 'LHR']
# ['Europe', 'United Kingdom', 'England and Wales', 'London', 'Luton Airport', 'LTN']
# ['Europe', 'United Kingdom', 'England and Wales', 'London', 'London Southend Airport', 'SEN']
# ['Europe', 'United Kingdom', 'England and Wales', 'London', 'London Stansted Airport', 'STN']
# ['Europe', 'United Kingdom', 'England and Wales', 'Manchester', 'Manchester Airport', 'MAN']
# ['Europe', 'United Kingdom', 'England and Wales', 'Newcastle upon Tyne', 'Newcastle Airport', 'NCL']
# ['Europe', 'United Kingdom', 'England and Wales', 'Newquay', 'Newquay Cornwall Airport', 'NQY']
# ['Europe', 'United Kingdom', 'England and Wales', 'Norwich', 'Norwich International Airport', 'NWI']
# ['Europe', 'United Kingdom', 'England and Wales', 'Southampton', 'Southampton Airport', 'SOU']
# ['Europe', 'United Kingdom', 'Scotland', 'Aberdeen', 'Aberdeen Airport', 'ABZ']
# ['Europe', 'United Kingdom', 'Scotland', 'Edinburgh', 'Edinburgh Airport', 'EDI']
# ['Europe', 'United Kingdom', 'Scotland', 'Glasgow', 'Glasgow International Airport', 'GLA']
# ['Europe', 'United Kingdom', 'Scotland', 'Glasgow', 'Glasgow Prestwick Airport', 'PIK']
# ['Europe', 'United Kingdom', 'Scotland', 'Inverness', 'Inverness Airport', 'INV']
# ['Europe', 'United Kingdom', 'Northern Ireland', 'Belfast', 'Belfast International Airport', 'BFS']
# ['Europe', 'United Kingdom', 'Northern Ireland', 'Belfast', 'George Best Belfast City Airport', 'BHD']
# ['Europe', 'United Kingdom', 'Northern Ireland', 'Derry', 'City of Derry Airport', 'LDY']
# ['Oceania', None, 'American Samoa', 'Pago Pago', 'Pago Pago International Airport', 'PPG']
# ['Oceania', None, 'Australia', 'Adelaide', 'Adelaide Airport', 'ADL']
# ['Oceania', None, 'Australia', 'Brisbane', 'Brisbane Airport', 'BNE']
# ['Oceania', None, 'Australia', 'Broome', 'Broome International Airport', 'BME']
# ['Oceania', None, 'Australia', 'Cairns', 'Cairns Airport', 'CNS']
# ['Oceania', None, 'Australia', 'Canberra', 'Canberra Airport', 'CBR']
# ['Oceania', None, 'Australia', 'Darwin', 'Darwin International Airport', 'DRW']
# ['Oceania', None, 'Australia', 'Geelong', 'Avalon Airport', 'AVV']
# ['Oceania', None, 'Australia', 'Gold Coast', 'Gold Coast Airport', 'OOL']
# ['Oceania', None, 'Australia', 'Hobart', 'Hobart Airport', 'HBA']
# ['Oceania', None, 'Australia', 'Melbourne', 'Melbourne Airport', 'MEL']
# ['Oceania', None, 'Australia', 'Newcastle', 'Newcastle Airport', 'NTL']
# ['Oceania', None, 'Australia', 'Perth', 'Perth Airport', 'PER']
# ['Oceania', None, 'Australia', 'Port Hedland', 'Port Hedland International Airport', 'PHE']
# ['Oceania', None, 'Australia', 'Sunshine Coast', 'Sunshine Coast Airport', 'MCY']
# ['Oceania', None, 'Australia', 'Sydney', 'Sydney Airport', 'SYD']
# ['Oceania', None, 'Australia', 'Townsville', 'Townsville Airport', 'TSV']
# ['Oceania', None, 'Christmas Island', 'Christmas Island', 'Christmas Island Airport', 'XCH']
# ['Oceania', None, 'Cocos (Keeling) Islands', 'Cocos (Keeling) Islands', 'Cocos (Keeling) Islands Airport', 'CCK']
# ['Oceania', None, 'Cook Islands', 'Rarotonga', 'Rarotonga Airport', 'RAR']
# ['Oceania', None, 'Easter Island', 'Hanga Roa', 'Mataveri International Airport', 'IPC']
# ['Oceania', None, 'Fiji', 'Nadi', 'Nadi International Airport', 'NAN']
# ['Oceania', None, 'Fiji', 'Suva', 'Nausori International Airport', 'SUV']
# ['Oceania', None, 'French Polynesia', 'Papeete', "Faa'a International Airport", 'PPT']
# ['Oceania', None, 'Guam', 'Hagåtña', 'Antonio B. Won Pat International Airport', 'GUM']
# ['Oceania', None, 'Kiribati', 'Kiritimati', 'Cassidy International Airport', 'CXI']
# ['Oceania', None, 'Kiribati', 'Tarawa', 'Bonriki International Airport', 'TRW']
# ['Oceania', None, 'Marshall Islands', 'Kwajalein', 'Bucholz Army Airfield', 'KWA']
# ['Oceania', None, 'Marshall Islands', 'Majuro', 'Marshall Islands International Airport', 'MAJ']
# ['Oceania', None, 'Federated States of Micronesia', 'Chuuk', 'Chuuk International Airport', 'TKK']
# ['Oceania', None, 'Federated States of Micronesia', 'Kosrae', 'Kosrae International Airport', 'KSA']
# ['Oceania', None, 'Federated States of Micronesia', 'Pohnpei', 'Pohnpei International Airport', 'PNI']
# ['Oceania', None, 'Federated States of Micronesia', 'Yap', 'Yap International Airport', 'YAP']
# ['Oceania', None, 'Nauru', 'Yaren District', 'Nauru International Airport', 'INU']
# ['Oceania', None, 'New Caledonia', 'Nouméa', 'La Tontouta International Airport', 'NOU']
# ['Oceania', None, 'New Zealand', 'Auckland', 'Auckland Airport', 'AKL']
# ['Oceania', None, 'New Zealand', 'Christchurch', 'Christchurch Airport', 'CHC']
# ['Oceania', None, 'New Zealand', 'Queenstown', 'Queenstown Airport', 'ZQN']
# ['Oceania', None, 'New Zealand', 'Wellington', 'Wellington Airport', 'WLG']
# ['Oceania', None, 'Norfolk Island', 'Norfolk Island', 'Norfolk Island Airport', 'NLK']
# ['Oceania', None, 'Northern Mariana Islands', 'Rota', 'Rota International Airport', 'ROP']
# ['Oceania', None, 'Northern Mariana Islands', 'Saipan', 'Saipan International Airport', 'SPN']
# ['Oceania', None, 'Northern Mariana Islands', 'Tinian', 'Tinian International Airport', 'TIQ']
# ['Oceania', None, 'Niue', 'Alofi', 'Niue International Airport', 'IUE']
# ['Oceania', None, 'Palau', 'Koror', 'Roman Tmetuchl International Airport', 'ROR']
# ['Oceania', None, 'Papua New Guinea', 'Port Moresby', 'Jacksons International Airport', 'POM']
# ['Oceania', None, 'Papua New Guinea', 'Mount Hagen', 'Mount Hagen Airport', 'HGU']
# ['Oceania', None, 'Samoa', 'Apia', 'Faleolo International Airport', 'APW']
# ['Oceania', None, 'Solomon Islands', 'Honiara', 'Honiara International Airport', 'HIR']
# ['Oceania', None, 'Tonga', 'Nukuʻalofa', 'Fuaʻamotu International Airport', 'TBU']
# ['Oceania', None, 'Tonga', 'Vavaʻu', 'Vavaʻu International Airport', 'VAV']
# ['Oceania', None, 'Tuvalu', 'Funafuti', 'Funafuti International Airport', 'FUN']
# ['Oceania', None, 'Vanuatu', 'Luganville', 'Santo-Pekoa International Airport', 'SON']
# ['Oceania', None, 'Vanuatu', 'Port Vila', 'Bauerfield International Airport', 'VLI']
# ['Oceania', None, 'Wallis and Futuna', 'Futuna', 'Pointe Vele Airport', 'FUT']
# ['Oceania', None, 'Wallis and Futuna', 'Wallis', 'Hihifo Airport', 'WLS']
