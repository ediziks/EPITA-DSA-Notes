# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sklearn 
import seaborn as sns

# %%
# data = pd.read_csv('0_example.txt', skiprows=0)
# data.sample()

df = pd.read_csv('1_binary_landscapes.txt', header=None, engine='python', sep='\t')
df = df[0].str.split('\s\s|\s', expand=True)
count = df.iloc[0]
df = df.drop(df.index[0])
df.rename(columns={0: 'Type', 1: 'TagNum'}, inplace=True)

df1 = df.iloc[:,0:2]
df2 = df.iloc[:,2:]
# df2 = df2.to_numpy()
df1['Tags'] = df2.apply(lambda s: s.to_numpy(), axis=1)

# remove none values from df['tags']
df1['Tags'] = df1['Tags'].apply(lambda s: s[s != np.array(None)])

df1.sample(10)
# Out:
# /var/folders/0k/369f7zf50c59w8dkhr5_kczr0000gn/T/ipykernel_16698/2648491679.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Tags'] = df2.apply(lambda s: s.to_numpy(), axis=1)
# /var/folders/0k/369f7zf50c59w8dkhr5_kczr0000gn/T/ipykernel_16698/2648491679.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Tags'] = df1['Tags'].apply(lambda s: s[s != np.array(None)])
#       Type TagNum                                               Tags
# ...
